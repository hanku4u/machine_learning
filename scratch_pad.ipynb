# %%
from docx import Document

# Create a new Word document
doc = Document()

# Title
doc.add_heading('Cybersecurity Model for TechHealth Solutions Inc.', level=1)
doc.add_paragraph('Prepared by: [Your Name]')
doc.add_paragraph('Date: [Insert Date]')

# Table of Contents
doc.add_heading('Table of Contents', level=2)
toc = """
1. Executive Summary
2. Introduction
3. Cybersecurity Objectives
4. Risk Assessment
5. Proposed Cybersecurity Model
   - Data Protection & Privacy
   - Incident Response & Business Continuity
   - Employee Security Awareness & Training
   - Identity & Access Management (IAM)
   - Network & Endpoint Security
   - Secure Software Development & Telemedicine Security
   - Vendor Security Management
6. Implementation Plan
7. Evaluation & Monitoring
8. Conclusion
9. Appendices
"""
doc.add_paragraph(toc)

# Executive Summary
doc.add_heading('1. Executive Summary', level=2)
doc.add_paragraph(
    "TechHealth Solutions Inc., a leading healthcare technology provider, is facing increasing cybersecurity threats due to its handling of sensitive patient data and reliance on cloud services and third-party vendors. "
    "Recent security incidents, including phishing attacks, ransomware infections, insider threats, and vulnerabilities in its telemedicine platform, highlight the urgent need for a comprehensive cybersecurity model."
)

doc.add_paragraph(
    "This report presents a multi-layered cybersecurity framework to enhance security, ensure regulatory compliance, and protect critical infrastructure. "
    "The model follows industry best practices, including NIST, HIPAA, ISO 27001, and Zero Trust Architecture (ZTA). "
    "The implementation roadmap outlines a strategic, phased approach to secure data, improve threat detection, and enhance system resilience."
)

# Introduction
doc.add_heading('2. Introduction', level=2)
doc.add_paragraph("TechHealth Solutions Inc. develops and provides software solutions for hospitals and healthcare providers, including:")
doc.add_paragraph("- Patient records management\n- Appointment scheduling\n- Billing and financial operations\n- Telemedicine services")

doc.add_paragraph("The organization has 500 employees spread across headquarters, remote offices, and data centers, with cloud-based infrastructure supporting non-sensitive applications.")

doc.add_heading("Cybersecurity Challenges", level=3)
doc.add_paragraph(
    "The company has recently faced severe cybersecurity incidents, including:\n"
    "1. Data Breach – A phishing attack exposed patient records.\n"
    "2. Ransomware Attack – Remote offices were targeted, causing operational downtime.\n"
    "3. Insider Threat – A former employee attempted unauthorized access.\n"
    "4. Telemedicine Vulnerability – A security flaw exposed doctor-patient communications.\n"
    "5. Third-Party Vendor Risks – Weak vendor security increased the risk of supply chain attacks."
)

# Cybersecurity Objectives
doc.add_heading('3. Cybersecurity Objectives', level=2)
doc.add_paragraph("The proposed cybersecurity model focuses on the CIA Triad to ensure:")
doc.add_paragraph("✅ Confidentiality – Protecting patient records from unauthorized access.")
doc.add_paragraph("✅ Integrity – Maintaining the accuracy and reliability of healthcare data.")
doc.add_paragraph("✅ Availability – Ensuring 24/7 access to critical healthcare systems.")

# Risk Assessment
doc.add_heading('4. Risk Assessment', level=2)
risk_table = [
    ["Cyber Threat", "Potential Impact"],
    ["Data Breach (Phishing Attack)", "Compromised patient data, legal liabilities, regulatory fines"],
    ["Ransomware Attack", "Disruption of healthcare operations, financial loss"],
    ["Insider Threat", "Unauthorized data access, system tampering"],
    ["Telemedicine Vulnerability", "Patient privacy violations, reputational damage"],
    ["Weak Third-Party Security", "Supply chain attack, unauthorized system access"]
]

table = doc.add_table(rows=len(risk_table), cols=2)
for i, row in enumerate(risk_table):
    for j, cell in enumerate(row):
        table.cell(i, j).text = cell

# Proposed Cybersecurity Model
doc.add_heading('5. Proposed Cybersecurity Model', level=2)
sections = [
    "5.1. Data Protection & Privacy",
    "5.2. Incident Response & Business Continuity",
    "5.3. Employee Security Awareness & Training",
    "5.4. Identity & Access Management (IAM)",
    "5.5. Network & Endpoint Security",
    "5.6. Secure Software Development & Telemedicine Security",
    "5.7. Vendor Security Management"
]

for section in sections:
    doc.add_heading(section, level=3)

# Implementation Plan
doc.add_heading('6. Implementation Plan', level=2)
timeline_table = [
    ["Timeline", "Action Items"],
    ["Month 1-3", "Establish cybersecurity governance, Implement MFA, Conduct security audit"],
    ["Month 4-6", "Deploy IDS/IPS, Encrypt data, Initiate security training programs"],
    ["Month 7-9", "Implement PAM, Test incident response, Strengthen telemedicine security"],
    ["Month 10-12", "Perform vendor audits, Deploy EDR, Strengthen disaster recovery plans"]
]

table = doc.add_table(rows=len(timeline_table), cols=2)
for i, row in enumerate(timeline_table):
    for j, cell in enumerate(row):
        table.cell(i, j).text = cell

# Evaluation & Monitoring
doc.add_heading('7. Evaluation & Monitoring', level=2)
doc.add_paragraph("Key Performance Indicators (KPIs) for ongoing monitoring:")
doc.add_paragraph("📊 Number of prevented cyber incidents (measures risk reduction).")
doc.add_paragraph("📊 Phishing simulation pass rate (tracks employee security awareness).")
doc.add_paragraph("📊 System uptime and incident response efficiency (assesses resilience).")
doc.add_paragraph("📊 Third-party security audit results (ensures vendor compliance).")

# Conclusion
doc.add_heading('8. Conclusion', level=2)
doc.add_paragraph(
    "By implementing this comprehensive cybersecurity model, TechHealth Solutions Inc. will:\n"
    "✅ Enhance data security and regulatory compliance (HIPAA, NIST, ISO 27001).\n"
    "✅ Improve threat detection and response to mitigate cyber incidents.\n"
    "✅ Strengthen employee awareness through training and simulations.\n"
    "✅ Secure telemedicine infrastructure to protect patient privacy.\n"
    "✅ Minimize vendor-related risks through stringent third-party assessments.\n\n"
    "A proactive cybersecurity approach ensures long-term security, operational continuity, and customer trust."
)

# Appendices
doc.add_heading('9. Appendices', level=2)
doc.add_paragraph("📌 Appendix A – NIST Cybersecurity Framework Summary")
doc.add_paragraph("📌 Appendix B – HIPAA Compliance Guidelines")
doc.add_paragraph("📌 Appendix C – Incident Response Policy Template")
doc.add_paragraph("📌 Appendix D – Employee Security Awareness Training Checklist")

# Save the document
file_path = "./TechHealth_Cybersecurity_Report.docx"
doc.save(file_path)

file_path
# Out:
# './TechHealth_Cybersecurity_Report.docx'
